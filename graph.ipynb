# %%
import matplotlib.pyplot as plt

sizes = [1000, 10000, 50000, 80000, 100000, 1000000]
time_shift = [0.014861699659377337, 0.2883721003308892, 2.778118799906224, 5.552470900118351, 0.38067420013249, 766.8621910996735]
time_LC = [0.010097499936819077, 0.07863839995115995, 0.5024212002754211, 0.777080999687314, 0.0020961998961866, 9.856853100005537]
time_standart = [0.005926999729126692, 0.08885159995406866, 0.39749620016664267, 0.6936042001470923, 0.8919456000439823, 8.855851700063795]
plt.plot(sizes, time_shift, label='ShiftXorGenerator', color="red")
plt.plot(sizes, time_LC, label='LCGenerator', color="orange")
plt.plot(sizes, time_standart, label='Random', color="yellow")
plt.xlabel("Объём данных", alpha=0.5)
plt.ylabel("Время генерации", alpha=0.5)
plt.legend()
plt.show()

# %%
sizes1 = [1000, 10000, 50000, 80000, 100000, 1000000]
plt.plot(sizes1, time_LC, label='LCGenerator', color="orange")
plt.plot(sizes1, time_standart, label='Random', color="yellow")
plt.xlabel("Объём данных", alpha=0.5)
plt.ylabel("Время генерации", alpha=0.5)
plt.legend()
plt.show()
